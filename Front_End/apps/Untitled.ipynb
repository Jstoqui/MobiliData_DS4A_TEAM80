# %%
import pandas as pd
import geopandas as gpd
from geopandas import GeoDataFrame

# %%
pd.read_csv(r'actor_vial.csv')
# Out:
#         CODIGO_SINIESTRO       FECHA     CONDICION  ESTADO  EDAD  \
# 0                4401420    1/1/2015     CONDUCTOR   ILESO  20.0
# 1                4401429    1/1/2015        PEATON  HERIDO  28.0
# 2                4401442    1/1/2015      PASAJERO  HERIDO  22.0
# 3                4401442    1/1/2015        PEATON  HERIDO  57.0
# 4                4401423    1/1/2015        PEATON  HERIDO  19.0
# 5                4401430    1/1/2015  MOTOCICLISTA  HERIDO  27.0
# 6                4401425    1/1/2015     CONDUCTOR   ILESO  29.0
# 7                4401425    1/1/2015     CONDUCTOR   ILESO  30.0
# 8                4401425    1/1/2015  MOTOCICLISTA   ILESO  34.0
# 9                4401433    1/1/2015     CONDUCTOR   ILESO  20.0
# 10               4401433    1/1/2015     CONDUCTOR   ILESO  22.0
# 11               4401438    1/1/2015        PEATON  HERIDO   9.0
# 12               4401429    1/1/2015     CONDUCTOR   ILESO  36.0
# ...

# %%
bitcarrier_shp = gpd.read_file('df_bctraveltimes_geom.shp')

# %%
bitcarrier_shp
# Out:
#                                               geometry
# 0    LINESTRING (-74.05141 4.66775, -74.04701 4.66523)
# 1    LINESTRING (-74.06176 4.65918, -74.06165 4.659...
# 2    LINESTRING (-74.05240 4.67569, -74.04820 4.67351)
# 3    MULTILINESTRING ((-74.06342 4.66922, -74.06343...
# 4    LINESTRING (-74.10227 4.58126, -74.10031 4.582...
# ..                                                 ...
# 916  LINESTRING (-74.11166 4.68156, -74.11079 4.684...
# 917  LINESTRING (-74.06209 4.70058, -74.05768 4.699...
# 918  LINESTRING (-74.04286 4.75071, -74.04475 4.751...
# 919  LINESTRING (-74.10899 4.67930, -74.11032 4.680...
# 920  LINESTRING (-74.11165 4.68174, -74.11405 4.683...
#
# [921 rows x 1 columns]
